# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/Ubion_project_2/train_Winsorization.csv', encoding='euc-kr')
test = pd.read_csv('/content/drive/MyDrive/Ubion_project_2/test.csv', encoding='euc-kr')

# %%
# train['자산총계(천원)'] = train['자산총계(천원)'] * 1000
# train['log자산총계'] = np.log(train['자산총계(천원)'])

# test['자산총계(천원)'] = test['자산총계(천원)'] * 1000
# test['log자산총계'] = np.log(test['자산총계(천원)'])

# %%
train['기업수명주기'] = train['기업수명주기'].map({
    '도입기' : 1,
    '성장기' : 2,
    '성숙기' : 3,
    '수축기' : 4,
    '쇠퇴기' : 5
}).astype('category')

test['기업수명주기'] = test['기업수명주기'].map({
    '도입기' : 1,
    '성장기' : 2,
    '성숙기' : 3,
    '수축기' : 4,
    '쇠퇴기' : 5
}).astype('category')

# %% [markdown]
# # Filter Method
# ## t-test & chi-square

# %% [markdown]
# - t-test 하기 위해 연속형 컬럼만 추출

# %%
train.columns
# Out:
# Index(['회사명', '거래소코드', 'Year', '부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도',
#        '자기자본구성비율', '매출액영업이익률', '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률',
#        '운전자본회전률', '순운전자본회전률', '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율',
#        '총자본증가율', '자기자본증가율', '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율',
#        '영업이익증가율', '총자본투자효율', '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'OCF이자보상배율',
#        '부채상환계수', '장기부채상환능력', '매출액대비금융비용상환능력', '연구개발비대비매출액', '매출액대비현금흐름',
#        '매출액대비잉여현금흐름', '총자산대비현금흐름', '총자산대비영업현금흐름', '총자산대비잉여현금흐름', '기업수명주기',
#        '이보배초과여부', '파부비초과여부', '파당비초과여부', '파차의초과여부', '파로이초과여부', 'log자산총계',
#        't-1감사의견코드'],
#       dtype='object')

# %%
train_int = train[['부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
      '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률', '재고자산회전률',
       '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율', '순이익증가율',
       '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율', '부가가치율',
       '노동소득분배율', '자본분배율', '이윤분배율', 'log자산총계',
       'OCF이자보상배율', '부채상환계수', '장기부채상환능력', '매출액대비금융비용상환능력', '연구개발비대비매출액', '매출액대비현금흐름',
       '매출액대비잉여현금흐름', '총자산대비현금흐름', '총자산대비영업현금흐름', '총자산대비잉여현금흐름',
       't-1감사의견코드']]

# %%
test_int = test[['부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
      '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률', '재고자산회전률',
       '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율', '순이익증가율',
       '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율', '부가가치율',
       '노동소득분배율', '자본분배율', '이윤분배율', 'log자산총계',
       'OCF이자보상배율', '부채상환계수', '장기부채상환능력', '매출액대비금융비용상환능력', '연구개발비대비매출액', '매출액대비현금흐름',
       '매출액대비잉여현금흐름', '총자산대비현금흐름', '총자산대비영업현금흐름', '총자산대비잉여현금흐름',
       't-1감사의견코드']]

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train = train_int.drop('t-1감사의견코드', axis=1)
y_train = train_int[['t-1감사의견코드']]

X_test = test_int.drop('t-1감사의견코드', axis=1)
y_test = test_int[['t-1감사의견코드']]

# %%
scaler = StandardScaler()
train_sc = scaler.fit_transform(X_train)
test_sc = scaler.transform(X_test)

# %%
train_sc = pd.DataFrame(train_sc, columns=X_train.columns)
test_sc = pd.DataFrame(test_sc, columns=X_test.columns)

# %%
# 스케일링 + 타겟 데이터프레임
train_sc_total = pd.concat([train_sc, y_train], axis=1)
test_sc_total = pd.concat([test_sc, y_test], axis=1)

# %% [markdown]
# # MDA

# %%
# 1-1 정규성 테스트(샤피로)
from scipy.stats import norm
from scipy import stats
from statsmodels.formula.api import ols
from scipy.stats import kstest

for j in train_sc_total.columns:
    a = stats.shapiro(train_sc_total[j])
    p = a.pvalue
    print(j,a)
# Out:
# 부채비율 ShapiroResult(statistic=0.24403750896453857, pvalue=0.0)
# 당좌비율 ShapiroResult(statistic=0.2609418034553528, pvalue=0.0)
# 유동비율 ShapiroResult(statistic=0.25839483737945557, pvalue=0.0)
# 이자보상배율 ShapiroResult(statistic=0.28382623195648193, pvalue=0.0)
# 차입금의존도 ShapiroResult(statistic=0.9394765496253967, pvalue=0.0)
# 자기자본구성비율 ShapiroResult(statistic=0.9559506177902222, pvalue=0.0)
# 매출액영업이익률 ShapiroResult(statistic=0.1464797854423523, pvalue=0.0)
# 자기자본순이익률 ShapiroResult(statistic=0.49838918447494507, pvalue=0.0)
# 총자본순이익률 ShapiroResult(statistic=0.7577058672904968, pvalue=0.0)
# 총자본회전률 ShapiroResult(statistic=0.6562888622283936, pvalue=0.0)
# 자기자본회전률 ShapiroResult(statistic=0.36522388458251953, pvalue=0.0)
# 운전자본회전률 ShapiroResult(statistic=0.12048518657684326, pvalue=0.0)
# 순운전자본회전률 ShapiroResult(statistic=0.7150239944458008, pvalue=0.0)
# 재고자산회전률 ShapiroResult(statistic=0.1800088882446289, pvalue=0.0)
# 당좌자산회전률 ShapiroResult(statistic=0.5666403770446777, pvalue=0.0)
# 유동자산회전률 ShapiroResult(statistic=0.615917980670929, pvalue=0.0)
# 매출액증가율 ShapiroResult(statistic=0.18934452533721924, pvalue=0.0)
# 총자본증가율 ShapiroResult(statistic=0.6742603182792664, pvalue=0.0)
# 자기자본증가율 ShapiroResult(statistic=0.3115989565849304, pvalue=0.0)
# 순이익증가율 ShapiroResult(statistic=0.2348254919052124, pvalue=0.0)
# 유형자산증가율 ShapiroResult(statistic=0.12091720104217529, pvalue=0.0)
# 유동자산증가율 ShapiroResult(statistic=0.41824668645858765, pvalue=0.0)
# 재고자산증가율 ShapiroResult(statistic=0.30345332622528076, pvalue=0.0)
# 영업이익증가율 ShapiroResult(statistic=0.27138930559158325, pvalue=0.0)
# 총자본투자효율 ShapiroResult(statistic=0.5634846091270447, pvalue=0.0)
# 부가가치율 ShapiroResult(statistic=0.1667192578315735, pvalue=0.0)
# 노동소득분배율 ShapiroResult(statistic=0.4553740620613098, pvalue=0.0)
# 자본분배율 ShapiroResult(statistic=0.5110419988632202, pvalue=0.0)
# 이윤분배율 ShapiroResult(statistic=0.30398017168045044, pvalue=0.0)
# log자산총계 ShapiroResult(statistic=0.9186384677886963, pvalue=0.0)
# OCF이자보상배율 ShapiroResult(statistic=0.31708335876464844, pvalue=0.0)
# 부채상환계수 ShapiroResult(statistic=0.16278129816055298, pvalue=0.0)
# 장기부채상환능력 ShapiroResult(statistic=0.24631458520889282, pvalue=0.0)
# 매출액대비금융비용상환능력 ShapiroResult(statistic=0.17854434251785278, pvalue=0.0)
# 연구개발비대비매출액 ShapiroResult(statistic=0.2700155973434448, pvalue=0.0)
# 매출액대비현금흐름 ShapiroResult(statistic=0.1393568515777588, pvalue=0.0)
# 매출액대비잉여현금흐름 ShapiroResult(statistic=0.12688618898391724, pvalue=0.0)
# 총자산대비현금흐름 ShapiroResult(statistic=0.7672125101089478, pvalue=0.0)
# 총자산대비영업현금흐름 ShapiroResult(statistic=0.8104975819587708, pvalue=0.0)
# 총자산대비잉여현금흐름 ShapiroResult(statistic=0.8354518413543701, pvalue=0.0)
# t-1감사의견코드 ShapiroResult(statistic=0.27632713317871094, pvalue=0.0)

# %%
# 1-2 정규성 테스트(K-S)
for j in train_sc_total.columns:
    a = kstest(train_sc_total[j],'norm')
    p = a.pvalue
    print(j,a)
# Out:
# 부채비율 KstestResult(statistic=0.3906751098050474, pvalue=0.0, statistic_location=-0.2775598980715014, statistic_sign=-1)
# 당좌비율 KstestResult(statistic=0.36984663905227333, pvalue=0.0, statistic_location=-0.3322595537125994, statistic_sign=-1)
# 유동비율 KstestResult(statistic=0.36477221111440783, pvalue=0.0, statistic_location=-0.34573161526781654, statistic_sign=-1)
# 이자보상배율 KstestResult(statistic=0.44220548347789634, pvalue=0.0, statistic_location=-0.1909002445930694, statistic_sign=1)
# 차입금의존도 KstestResult(statistic=0.10606206285734993, pvalue=0.0, statistic_location=-1.247745901800868, statistic_sign=-1)
# 자기자본구성비율 KstestResult(statistic=0.0758168364052138, pvalue=0.0, statistic_location=-1.4333778461001914, statistic_sign=-1)
# 매출액영업이익률 KstestResult(statistic=0.4196833421850839, pvalue=0.0, statistic_location=-0.010666213688669017, statistic_sign=-1)
# 자기자본순이익률 KstestResult(statistic=0.27273314810430427, pvalue=0.0, statistic_location=-0.2716236761529744, statistic_sign=-1)
# 총자본순이익률 KstestResult(statistic=0.1714237091573784, pvalue=0.0, statistic_location=-0.40925881627172556, statistic_sign=-1)
# 총자본회전률 KstestResult(statistic=0.21622730717583585, pvalue=0.0, statistic_location=-0.7849734403297831, statistic_sign=-1)
# 자기자본회전률 KstestResult(statistic=0.3400114167630336, pvalue=0.0, statistic_location=-0.4124121486430605, statistic_sign=-1)
# 운전자본회전률 KstestResult(statistic=0.440719230732214, pvalue=0.0, statistic_location=-0.14914595889692092, statistic_sign=-1)
# 순운전자본회전률 KstestResult(statistic=0.17451525441685328, pvalue=0.0, statistic_location=-0.9364714434237268, statistic_sign=-1)
# 재고자산회전률 KstestResult(statistic=0.4225574914190741, pvalue=0.0, statistic_location=-0.19535507637947927, statistic_sign=-1)
# 당좌자산회전률 KstestResult(statistic=0.22971883596399545, pvalue=0.0, statistic_location=-0.7397731198004573, statistic_sign=-1)
# 유동자산회전률 KstestResult(statistic=0.21120788944722924, pvalue=0.0, statistic_location=-0.8022371701156943, statistic_sign=-1)
# 매출액증가율 KstestResult(statistic=0.3853003597949959, pvalue=0.0, statistic_location=0.053417953445754424, statistic_sign=1)
# 총자본증가율 KstestResult(statistic=0.19943204948213467, pvalue=0.0, statistic_location=0.16521832110768506, statistic_sign=1)
# 자기자본증가율 KstestResult(statistic=0.3245422087685229, pvalue=0.0, statistic_location=0.11254690363607935, statistic_sign=1)
# 순이익증가율 KstestResult(statistic=0.3568358714235249, pvalue=0.0, statistic_location=0.033607264016140385, statistic_sign=1)
# 유형자산증가율 KstestResult(statistic=0.4179186353579052, pvalue=0.0, statistic_location=0.021172012990349976, statistic_sign=1)
# 유동자산증가율 KstestResult(statistic=0.2729866205687924, pvalue=0.0, statistic_location=0.17379121794667726, statistic_sign=1)
# 재고자산증가율 KstestResult(statistic=0.31825115258714576, pvalue=0.0, statistic_location=0.08965599482745439, statistic_sign=1)
# 영업이익증가율 KstestResult(statistic=0.34153092771575766, pvalue=0.0, statistic_location=0.02958443183957866, statistic_sign=1)
# 총자본투자효율 KstestResult(statistic=0.19869453990813113, pvalue=0.0, statistic_location=0.2731066534449901, statistic_sign=1)
# 부가가치율 KstestResult(statistic=0.41863708805642735, pvalue=0.0, statistic_location=-0.07646660693498988, statistic_sign=-1)
# 노동소득분배율 KstestResult(statistic=0.26340472122531183, pvalue=0.0, statistic_location=-0.6319499817359521, statistic_sign=-1)
# 자본분배율 KstestResult(statistic=0.21018761493395466, pvalue=0.0, statistic_location=0.8047129425915325, statistic_sign=1)
# 이윤분배율 KstestResult(statistic=0.34489194746896823, pvalue=0.0, statistic_location=-0.050817261221572964, statistic_sign=-1)
# log자산총계 KstestResult(statistic=0.09234517231883654, pvalue=0.0, statistic_location=0.056854806112461354, statistic_sign=1)
# OCF이자보상배율 KstestResult(statistic=0.44101606132894566, pvalue=0.0, statistic_location=-0.19109016112649296, statistic_sign=1)
# 부채상환계수 KstestResult(statistic=0.40683538108251005, pvalue=0.0, statistic_location=-0.03424790830151205, statistic_sign=-1)
# 장기부채상환능력 KstestResult(statistic=0.408169667250878, pvalue=0.0, statistic_location=-0.06695902411907581, statistic_sign=-1)
# 매출액대비금융비용상환능력 KstestResult(statistic=0.3964444767426863, pvalue=0.0, statistic_location=-0.046066189101428845, statistic_sign=-1)
# 연구개발비대비매출액 KstestResult(statistic=0.39814590170050246, pvalue=0.0, statistic_location=-0.25803620792371107, statistic_sign=-1)
# 매출액대비현금흐름 KstestResult(statistic=0.4198747555578731, pvalue=0.0, statistic_location=0.05704413300014037, statistic_sign=1)
# 매출액대비잉여현금흐름 KstestResult(statistic=0.4466903033737711, pvalue=0.0, statistic_location=0.031619458288601, statistic_sign=-1)
# 총자산대비현금흐름 KstestResult(statistic=0.17950092471513512, pvalue=0.0, statistic_location=0.22737031675584268, statistic_sign=1)
# 총자산대비영업현금흐름 KstestResult(statistic=0.1564344214632537, pvalue=0.0, statistic_location=-0.4326675635089554, statistic_sign=-1)
# 총자산대비잉여현금흐름 KstestResult(statistic=0.1602290159525639, pvalue=0.0, statistic_location=-0.22356651833618765, statistic_sign=-1)
# t-1감사의견코드 KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)

# %% [markdown]
# p-value가 0 이는 데이터개수가 많아서 p-value 자체가 너무작아 계산이 불가능하다고 판단. 중심극한 정리에 의해서 정규성이 있다고 가정하고 진행

# %%
# 부도기업과 정상기업의 피처별 등분산비교 (정규성 가정으로 bartlett)
Bad = train_sc_total[train_sc_total['t-1감사의견코드']== 1] #Existing Customer
Good = train_sc_total[train_sc_total['t-1감사의견코드']== 0] #Attrited Customer

c = []
for i in train_sc_total:
    # lresult = stats.levene(close[i], normal[i])
    lresult = stats.bartlett(Bad[i], Good[i])
    c.append([i,lresult[-1]])

c= pd.DataFrame(c)
c.columns=["피처값",'F-test']
c
# Out:
#               피처값         F-test
# 0            부채비율  8.773001e-268
# 1            당좌비율   0.000000e+00
# 2            유동비율   0.000000e+00
# 3          이자보상배율  8.292492e-237
# 4          차입금의존도   5.671281e-05
# 5        자기자본구성비율   1.167465e-94
# 6        매출액영업이익률   2.306937e-01
# 7        자기자본순이익률   0.000000e+00
# 8         총자본순이익률   0.000000e+00
# 9          총자본회전률   0.000000e+00
# 10        자기자본회전률   0.000000e+00
# 11        운전자본회전률  9.391575e-152
# 12       순운전자본회전률   0.000000e+00
# 13        재고자산회전률  6.380853e-264
# 14        당좌자산회전률   0.000000e+00
# 15        유동자산회전률   0.000000e+00
# 16         매출액증가율   0.000000e+00
# 17         총자본증가율   0.000000e+00
# 18        자기자본증가율   0.000000e+00
# 19         순이익증가율   0.000000e+00
# 20        유형자산증가율   0.000000e+00
# 21        유동자산증가율   0.000000e+00
# 22        재고자산증가율   0.000000e+00
# 23        영업이익증가율   0.000000e+00
# 24        총자본투자효율   4.463002e-01
# 25          부가가치율   2.951770e-01
# 26        노동소득분배율   6.581281e-30
# 27          자본분배율   9.076037e-24
# 28          이윤분배율   4.064004e-44
# 29        log자산총계   0.000000e+00
# 30      OCF이자보상배율   0.000000e+00
# 31         부채상환계수  6.724694e-137
# 32       장기부채상환능력   5.490238e-09
# 33  매출액대비금융비용상환능력   0.000000e+00
# 34     연구개발비대비매출액   2.028228e-05
# 35      매출액대비현금흐름   1.535609e-77
# 36    매출액대비잉여현금흐름   5.374400e-55
# 37      총자산대비현금흐름   8.763094e-01
# 38    총자산대비영업현금흐름   0.000000e+00
# 39    총자산대비잉여현금흐름   0.000000e+00
# 40      t-1감사의견코드            NaN

# %%
# F-test 결과 0.05 이상이면 homo 0.05 이하이면 hetero
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
    else:
        c.loc[i,"분산"] = "hetero"
c
# Out:
#               피처값         F-test      분산 T-test
# 0            부채비율  8.773001e-268  hetero
# 1            당좌비율   0.000000e+00  hetero
# 2            유동비율   0.000000e+00  hetero
# 3          이자보상배율  8.292492e-237  hetero
# 4          차입금의존도   5.671281e-05  hetero
# 5        자기자본구성비율   1.167465e-94  hetero
# 6        매출액영업이익률   2.306937e-01    homo
# 7        자기자본순이익률   0.000000e+00  hetero
# 8         총자본순이익률   0.000000e+00  hetero
# 9          총자본회전률   0.000000e+00  hetero
# 10        자기자본회전률   0.000000e+00  hetero
# 11        운전자본회전률  9.391575e-152  hetero
# 12       순운전자본회전률   0.000000e+00  hetero
# 13        재고자산회전률  6.380853e-264  hetero
# 14        당좌자산회전률   0.000000e+00  hetero
# 15        유동자산회전률   0.000000e+00  hetero
# 16         매출액증가율   0.000000e+00  hetero
# 17         총자본증가율   0.000000e+00  hetero
# 18        자기자본증가율   0.000000e+00  hetero
# 19         순이익증가율   0.000000e+00  hetero
# 20        유형자산증가율   0.000000e+00  hetero
# 21        유동자산증가율   0.000000e+00  hetero
# 22        재고자산증가율   0.000000e+00  hetero
# 23        영업이익증가율   0.000000e+00  hetero
# 24        총자본투자효율   4.463002e-01    homo
# 25          부가가치율   2.951770e-01    homo
# 26        노동소득분배율   6.581281e-30  hetero
# 27          자본분배율   9.076037e-24  hetero
# 28          이윤분배율   4.064004e-44  hetero
# 29        log자산총계   0.000000e+00  hetero
# 30      OCF이자보상배율   0.000000e+00  hetero
# 31         부채상환계수  6.724694e-137  hetero
# 32       장기부채상환능력   5.490238e-09  hetero
# 33  매출액대비금융비용상환능력   0.000000e+00  hetero
# 34     연구개발비대비매출액   2.028228e-05  hetero
# 35      매출액대비현금흐름   1.535609e-77  hetero
# 36    매출액대비잉여현금흐름   5.374400e-55  hetero
# 37      총자산대비현금흐름   8.763094e-01    homo
# 38    총자산대비영업현금흐름   0.000000e+00  hetero
# 39    총자산대비잉여현금흐름   0.000000e+00  hetero
# 40      t-1감사의견코드            NaN  hetero

# %%
c[c["분산"]=='homo']
# Out:
#           피처값    F-test    분산 T-test
# 6    매출액영업이익률  0.230694  homo
# 24    총자본투자효율  0.446300  homo
# 25      부가가치율  0.295177  homo
# 37  총자산대비현금흐름  0.876309  homo

# %%
c
# Out:
#               피처값         F-test      분산 T-test
# 0            부채비율  8.773001e-268  hetero
# 1            당좌비율   0.000000e+00  hetero
# 2            유동비율   0.000000e+00  hetero
# 3          이자보상배율  8.292492e-237  hetero
# 4          차입금의존도   5.671281e-05  hetero
# 5        자기자본구성비율   1.167465e-94  hetero
# 6        매출액영업이익률   2.306937e-01    homo
# 7        자기자본순이익률   0.000000e+00  hetero
# 8         총자본순이익률   0.000000e+00  hetero
# 9          총자본회전률   0.000000e+00  hetero
# 10        자기자본회전률   0.000000e+00  hetero
# 11        운전자본회전률  9.391575e-152  hetero
# 12       순운전자본회전률   0.000000e+00  hetero
# 13        재고자산회전률  6.380853e-264  hetero
# 14        당좌자산회전률   0.000000e+00  hetero
# 15        유동자산회전률   0.000000e+00  hetero
# 16         매출액증가율   0.000000e+00  hetero
# 17         총자본증가율   0.000000e+00  hetero
# 18        자기자본증가율   0.000000e+00  hetero
# 19         순이익증가율   0.000000e+00  hetero
# 20        유형자산증가율   0.000000e+00  hetero
# 21        유동자산증가율   0.000000e+00  hetero
# 22        재고자산증가율   0.000000e+00  hetero
# 23        영업이익증가율   0.000000e+00  hetero
# 24        총자본투자효율   4.463002e-01    homo
# 25          부가가치율   2.951770e-01    homo
# 26        노동소득분배율   6.581281e-30  hetero
# 27          자본분배율   9.076037e-24  hetero
# 28          이윤분배율   4.064004e-44  hetero
# 29        log자산총계   0.000000e+00  hetero
# 30      OCF이자보상배율   0.000000e+00  hetero
# 31         부채상환계수  6.724694e-137  hetero
# 32       장기부채상환능력   5.490238e-09  hetero
# 33  매출액대비금융비용상환능력   0.000000e+00  hetero
# 34     연구개발비대비매출액   2.028228e-05  hetero
# 35      매출액대비현금흐름   1.535609e-77  hetero
# 36    매출액대비잉여현금흐름   5.374400e-55  hetero
# 37      총자산대비현금흐름   8.763094e-01    homo
# 38    총자산대비영업현금흐름   0.000000e+00  hetero
# 39    총자산대비잉여현금흐름   0.000000e+00  hetero
# 40      t-1감사의견코드            NaN  hetero

# %%
# homo 인 feature 는 student t-test, hetero이면 Welchs T-Test 진행
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=True)       ## equal_var = True Student T-test
        c.loc[i,"T-test"] = result[-1]
        print(Bad[c.loc[i,"피처값"]])
    else:
        c.loc[i,"분산"] = "hetero"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=False)      ## equal_var = False Welchs T-Test
        c.loc[i,"T-test"] = result[-1]
c
# Out:
# 8         -1.581632
# 9        -12.349735
# 25         0.029493
# 27        -0.025061
# 33        -0.125942
#             ...
# 137604     0.100578
# 137622     0.104771
# 137624     0.102997
# 137628     0.102392
# 137663     0.096989
# Name: 매출액영업이익률, Length: 9602, dtype: float64
# 8        -0.614022
# 9        -0.776401
# 25       -0.463187
# 27       -0.746979
# 33       -0.010685
#             ...
# 137604   -0.460953
# 137622   -0.295594
# 137624    0.117431
# 137628    0.542374
# 137663    0.197503
# Name: 총자본투자효율, Length: 9602, dtype: float64
# 8        -0.294838
# 9        -5.558117
# 25       -0.006468
# 27       -0.064376
# 33        0.441486
#             ...
# 137604   -0.026444
# 137622    0.001288
# 137624   -0.000765
# 137628   -0.002785
# 137663    0.005785
# Name: 부가가치율, Length: 9602, dtype: float64
# 8        -0.123710
# 9        -0.069908
# 25       -0.031936
# 27       -0.060454
# 33        1.673774
#             ...
# 137604    0.262653
# 137622    0.315837
# 137624    0.849720
# 137628   -0.197040
# 137663   -0.121098
# Name: 총자산대비현금흐름, Length: 9602, dtype: float64
#               피처값         F-test      분산    T-test
# 0            부채비율  8.773001e-268  hetero       0.0
# 1            당좌비율   0.000000e+00  hetero       0.0
# 2            유동비율   0.000000e+00  hetero       0.0
# 3          이자보상배율  8.292492e-237  hetero       0.0
# 4          차입금의존도   5.671281e-05  hetero       0.0
# 5        자기자본구성비율   1.167465e-94  hetero       0.0
# 6        매출액영업이익률   2.306937e-01    homo  0.034306
# 7        자기자본순이익률   0.000000e+00  hetero  0.000104
# 8         총자본순이익률   0.000000e+00  hetero       0.0
# 9          총자본회전률   0.000000e+00  hetero       0.0
# 10        자기자본회전률   0.000000e+00  hetero       0.0
# 11        운전자본회전률  9.391575e-152  hetero  0.025077
# 12       순운전자본회전률   0.000000e+00  hetero       0.0
# 13        재고자산회전률  6.380853e-264  hetero  0.018824
# 14        당좌자산회전률   0.000000e+00  hetero       0.0
# 15        유동자산회전률   0.000000e+00  hetero       0.0
# 16         매출액증가율   0.000000e+00  hetero       0.0
# 17         총자본증가율   0.000000e+00  hetero       0.0
# 18        자기자본증가율   0.000000e+00  hetero       0.0
# 19         순이익증가율   0.000000e+00  hetero       0.0
# 20        유형자산증가율   0.000000e+00  hetero       0.0
# 21        유동자산증가율   0.000000e+00  hetero       0.0
# 22        재고자산증가율   0.000000e+00  hetero       0.0
# 23        영업이익증가율   0.000000e+00  hetero       0.0
# 24        총자본투자효율   4.463002e-01    homo  0.006248
# 25          부가가치율   2.951770e-01    homo       0.0
# 26        노동소득분배율   6.581281e-30  hetero  0.000002
# 27          자본분배율   9.076037e-24  hetero       0.0
# 28          이윤분배율   4.064004e-44  hetero  0.000997
# 29        log자산총계   0.000000e+00  hetero       0.0
# 30      OCF이자보상배율   0.000000e+00  hetero       0.0
# 31         부채상환계수  6.724694e-137  hetero  0.334821
# 32       장기부채상환능력   5.490238e-09  hetero       0.0
# 33  매출액대비금융비용상환능력   0.000000e+00  hetero  0.000001
# 34     연구개발비대비매출액   2.028228e-05  hetero   0.80436
# 35      매출액대비현금흐름   1.535609e-77  hetero  0.468041
# 36    매출액대비잉여현금흐름   5.374400e-55  hetero  0.000016
# 37      총자산대비현금흐름   8.763094e-01    homo       0.0
# 38    총자산대비영업현금흐름   0.000000e+00  hetero       0.0
# 39    총자산대비잉여현금흐름   0.000000e+00  hetero       0.0
# 40      t-1감사의견코드            NaN  hetero       0.0

# %%
# 0.05 이상이면 유의미하지 않으므로 0.05 이하인 것만 추출
d = c[c["T-test"]<= 0.05]
d.sort_values('T-test',ascending=False)["피처값"].unique()
# d.sort_values('T-test',ascending=False)["피처값"]
# Out:
# array(['매출액영업이익률', '운전자본회전률', '재고자산회전률', '총자본투자효율', '이윤분배율', '자기자본순이익률',
#        '매출액대비잉여현금흐름', '노동소득분배율', '매출액대비금융비용상환능력', '자본분배율', '부가가치율',
#        '장기부채상환능력', '유동비율', '부채비율', '총자본순이익률', '총자산대비현금흐름', '이자보상배율',
#        '총자산대비영업현금흐름', '유형자산증가율', '당좌비율', 'OCF이자보상배율', '매출액증가율', '재고자산증가율',
#        '유동자산증가율', '영업이익증가율', '자기자본증가율', '순이익증가율', '총자본증가율', '자기자본회전률',
#        '차입금의존도', '유동자산회전률', 'log자산총계', '당좌자산회전률', '순운전자본회전률', '총자본회전률',
#        '자기자본구성비율', '총자산대비잉여현금흐름', 't-1감사의견코드'], dtype=object)

# %%
d.sort_values('T-test',ascending=False).dropna()
# Out:
#               피처값         F-test      분산    T-test
# 6        매출액영업이익률   2.306937e-01    homo  0.034306
# 11        운전자본회전률  9.391575e-152  hetero  0.025077
# 13        재고자산회전률  6.380853e-264  hetero  0.018824
# 24        총자본투자효율   4.463002e-01    homo  0.006248
# 28          이윤분배율   4.064004e-44  hetero  0.000997
# 7        자기자본순이익률   0.000000e+00  hetero  0.000104
# 36    매출액대비잉여현금흐름   5.374400e-55  hetero  0.000016
# 26        노동소득분배율   6.581281e-30  hetero  0.000002
# 33  매출액대비금융비용상환능력   0.000000e+00  hetero  0.000001
# 27          자본분배율   9.076037e-24  hetero       0.0
# 25          부가가치율   2.951770e-01    homo       0.0
# 32       장기부채상환능력   5.490238e-09  hetero       0.0
# 2            유동비율   0.000000e+00  hetero       0.0
# 0            부채비율  8.773001e-268  hetero       0.0
# 8         총자본순이익률   0.000000e+00  hetero       0.0
# 37      총자산대비현금흐름   8.763094e-01    homo       0.0
# 3          이자보상배율  8.292492e-237  hetero       0.0
# 38    총자산대비영업현금흐름   0.000000e+00  hetero       0.0
# 20        유형자산증가율   0.000000e+00  hetero       0.0
# 1            당좌비율   0.000000e+00  hetero       0.0
# 30      OCF이자보상배율   0.000000e+00  hetero       0.0
# 16         매출액증가율   0.000000e+00  hetero       0.0
# 22        재고자산증가율   0.000000e+00  hetero       0.0
# 21        유동자산증가율   0.000000e+00  hetero       0.0
# 23        영업이익증가율   0.000000e+00  hetero       0.0
# 18        자기자본증가율   0.000000e+00  hetero       0.0
# 19         순이익증가율   0.000000e+00  hetero       0.0
# 17         총자본증가율   0.000000e+00  hetero       0.0
# 10        자기자본회전률   0.000000e+00  hetero       0.0
# 4          차입금의존도   5.671281e-05  hetero       0.0
# 15        유동자산회전률   0.000000e+00  hetero       0.0
# 29        log자산총계   0.000000e+00  hetero       0.0
# 14        당좌자산회전률   0.000000e+00  hetero       0.0
# 12       순운전자본회전률   0.000000e+00  hetero       0.0
# 9          총자본회전률   0.000000e+00  hetero       0.0
# 5        자기자본구성비율   1.167465e-94  hetero       0.0
# 39    총자산대비잉여현금흐름   0.000000e+00  hetero       0.0

# %%
d['피처값'].values
# Out:
# array(['부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
#        '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률',
#        '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율',
#        '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율',
#        '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'log자산총계', 'OCF이자보상배율',
#        '장기부채상환능력', '매출액대비금융비용상환능력', '매출액대비잉여현금흐름', '총자산대비현금흐름',
#        '총자산대비영업현금흐름', '총자산대비잉여현금흐름', 't-1감사의견코드'], dtype=object)

# %%
fea = ['부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
       '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률',
       '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율',
       '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율',
       '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'log자산총계', 'OCF이자보상배율',
       '장기부채상환능력', '매출액대비금융비용상환능력', '매출액대비잉여현금흐름', '총자산대비현금흐름',
       '총자산대비영업현금흐름', '총자산대비잉여현금흐름'
       ]
mda_feature = train[fea]
mda_feature
# Out:
#            부채비율    당좌비율    유동비율      이자보상배율  차입금의존도  자기자본구성비율  매출액영업이익률  \
# 0       1251.02  347.96  354.61  -13.357516    6.09      7.40   -414.90
# 1        107.19   68.72   68.72    8.709388   45.96     48.26     25.08
# 2        399.11  109.86  109.86 -198.699143    0.00     20.04    -17.15
# 3        267.34   55.31   55.31   14.620331   70.59     27.22     60.12
# 4        390.03   30.73  124.85   13.221831    1.76     20.41     28.90
# ...         ...     ...     ...         ...     ...       ...       ...
# 137673   400.62   84.46  129.25   12.957288   19.60     19.98      6.17
# 137674   135.02  148.14  158.66    6.055733   25.22     42.55      4.29
# 137675    50.03  223.79  300.12   52.200088   18.78     66.65     20.22
# 137676    27.20  272.56  280.21  -21.661011    7.13     78.62      1.88
# 137677  3098.11    7.74    7.74    7.037306   32.75      3.13     24.77
#
#         자기자본순이익률  총자본순이익률  총자본회전률  ...  자본분배율  이윤분배율    log자산총계   OCF이자보상배율  \
# 0        -826.27   -82.59    0.17  ...   0.00   0.00  22.828067   -9.332108
# 1          13.81     6.61    0.36  ...  79.24  42.80  23.977288    9.548280
# 2         -12.57    -1.80    0.10  ...   6.81 -30.69  23.592060 -618.027372
# 3          66.76    18.17    0.40  ...  86.58  61.48  23.265147    5.010647
# 4         408.97    27.88    1.17  ...  95.29  76.32  23.488822   16.602420
# ...          ...      ...     ...  ...    ...    ...        ...         ...
# 137673     67.90    10.04    2.20  ...  55.69  32.77  23.805059    4.818200
# 137674      9.33     3.32    3.04  ...  56.58  18.05  25.560289    4.835895
# 137675     58.72    36.01    2.00  ...  77.57  59.76  22.865585   40.753692
# 137676      1.88     1.43    0.88  ...  65.89  26.06  24.057147   40.446933
# 137677     68.38     1.61    0.28  ...  62.26   9.48  24.213767    4.299987
#
#         장기부채상환능력  매출액대비금융비용상환능력  매출액대비잉여현금흐름  총자산대비현금흐름  총자산대비영업현금흐름  \
# 0      -0.000000       4.174742    -2.629424   0.772454    -0.244115
# 1       2.352094      56.802819     0.189178   0.000884     0.100369
# 2      -0.000000     -23.752940    -3.552263  -0.373468    -0.518387
# 3       4.843848      26.994572    -3.969096  -0.149208     0.041456
# 4       0.000000      46.704264     0.362891  -0.001722     0.418095
# ...          ...            ...          ...        ...          ...
# 137673  0.000000     213.217431     0.022309  -0.003247     0.050929
# 137674  0.036460     195.625970     0.036524  -0.018967     0.118604
# 137675  0.163392     288.357414     0.128391   0.215584     0.262040
# 137676  0.295099    -288.743530     0.073553   0.063097     0.050614
# 137677  0.696463      32.488890     0.021335  -0.000420     0.041363
#
#         총자산대비잉여현금흐름
# 0         -0.221444
# 1          0.069046
# 2         -0.516536
# 3         -0.798633
# 4          0.418095
# ...             ...
# 137673     0.049512
# 137674     0.126453
# 137675     0.213073
# 137676     0.066068
# 137677     0.005828
#
# [137678 rows x 37 columns]

# %%
def vif(data):
    import pandas as pd
    from statsmodels.stats.outliers_influence import variance_inflation_factor

    # VIF 출력을 위한 데이터 프레임 형성
    vif = pd.DataFrame()

    # VIF 값과 각 Feature 이름에 대해 설정
    vif["VIF Factor"] = [variance_inflation_factor(data.values, i) for i in range(len(data.columns))]
    vif["features"] = data.columns

    # VIF 값이 높은 순으로 정렬
    vif = vif.sort_values(by="VIF Factor", ascending=False)
    vif = vif.reset_index().drop(columns='index')

    return vif

vif(mda_feature)
# Out:
#     VIF Factor       features
# 0    31.387494        log자산총계
# 1    12.714899           당좌비율
# 2    12.586102           유동비율
# 3     9.932378          자본분배율
# 4     9.735564       자기자본구성비율
# 5     9.513582        노동소득분배율
# 6     9.266639       순운전자본회전률
# 7     7.621522         차입금의존도
# 8     6.981453        유동자산회전률
# 9     6.938925         총자본회전률
# 10    5.240231        당좌자산회전률
# 11    2.774384      OCF이자보상배율
# 12    2.767111         이자보상배율
# 13    2.621809          이윤분배율
# 14    2.534931    총자산대비잉여현금흐름
# 15    2.321493        총자본순이익률
# 16    2.202255    총자산대비영업현금흐름
# 17    2.122094        총자본투자효율
# 18    2.091738        자기자본회전률
# 19    2.031261       매출액영업이익률
# 20    1.743294         총자본증가율
# 21    1.705680    매출액대비잉여현금흐름
# 22    1.691534          부가가치율
# 23    1.548754           부채비율
# 24    1.518286       자기자본순이익률
# 25    1.317047        유동자산증가율
# 26    1.254356      총자산대비현금흐름
# 27    1.222088        자기자본증가율
# 28    1.180696        운전자본회전률
# 29    1.151119         순이익증가율
# 30    1.142138        영업이익증가율
# 31    1.096296         매출액증가율
# 32    1.092783        재고자산증가율
# 33    1.061944        재고자산회전률
# 34    1.042988        유형자산증가율
# 35    1.034890  매출액대비금융비용상환능력
# 36    1.029761       장기부채상환능력

# %%
# log자산총계 삭제
fea = ['부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
       '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률',
       '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율',
       '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율',
       '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'OCF이자보상배율',
       '장기부채상환능력', '매출액대비금융비용상환능력', '매출액대비잉여현금흐름', '총자산대비현금흐름',
       '총자산대비영업현금흐름', '총자산대비잉여현금흐름'
       ]
mda_feature2 = train[fea]
mda_feature2
# Out:
#            부채비율    당좌비율    유동비율      이자보상배율  차입금의존도  자기자본구성비율  매출액영업이익률  \
# 0       1251.02  347.96  354.61  -13.357516    6.09      7.40   -414.90
# 1        107.19   68.72   68.72    8.709388   45.96     48.26     25.08
# 2        399.11  109.86  109.86 -198.699143    0.00     20.04    -17.15
# 3        267.34   55.31   55.31   14.620331   70.59     27.22     60.12
# 4        390.03   30.73  124.85   13.221831    1.76     20.41     28.90
# ...         ...     ...     ...         ...     ...       ...       ...
# 137673   400.62   84.46  129.25   12.957288   19.60     19.98      6.17
# 137674   135.02  148.14  158.66    6.055733   25.22     42.55      4.29
# 137675    50.03  223.79  300.12   52.200088   18.78     66.65     20.22
# 137676    27.20  272.56  280.21  -21.661011    7.13     78.62      1.88
# 137677  3098.11    7.74    7.74    7.037306   32.75      3.13     24.77
#
#         자기자본순이익률  총자본순이익률  총자본회전률  ...  노동소득분배율  자본분배율  이윤분배율   OCF이자보상배율  \
# 0        -826.27   -82.59    0.17  ...     0.00   0.00   0.00   -9.332108
# 1          13.81     6.61    0.36  ...    20.76  79.24  42.80    9.548280
# 2         -12.57    -1.80    0.10  ...    93.19   6.81 -30.69 -618.027372
# 3          66.76    18.17    0.40  ...    13.42  86.58  61.48    5.010647
# 4         408.97    27.88    1.17  ...     4.71  95.29  76.32   16.602420
# ...          ...      ...     ...  ...      ...    ...    ...         ...
# 137673     67.90    10.04    2.20  ...    44.31  55.69  32.77    4.818200
# 137674      9.33     3.32    3.04  ...    43.42  56.58  18.05    4.835895
# 137675     58.72    36.01    2.00  ...    22.43  77.57  59.76   40.753692
# 137676      1.88     1.43    0.88  ...    34.11  65.89  26.06   40.446933
# 137677     68.38     1.61    0.28  ...    37.74  62.26   9.48    4.299987
#
#         장기부채상환능력  매출액대비금융비용상환능력  매출액대비잉여현금흐름  총자산대비현금흐름  총자산대비영업현금흐름  \
# 0      -0.000000       4.174742    -2.629424   0.772454    -0.244115
# 1       2.352094      56.802819     0.189178   0.000884     0.100369
# 2      -0.000000     -23.752940    -3.552263  -0.373468    -0.518387
# 3       4.843848      26.994572    -3.969096  -0.149208     0.041456
# 4       0.000000      46.704264     0.362891  -0.001722     0.418095
# ...          ...            ...          ...        ...          ...
# 137673  0.000000     213.217431     0.022309  -0.003247     0.050929
# 137674  0.036460     195.625970     0.036524  -0.018967     0.118604
# 137675  0.163392     288.357414     0.128391   0.215584     0.262040
# 137676  0.295099    -288.743530     0.073553   0.063097     0.050614
# 137677  0.696463      32.488890     0.021335  -0.000420     0.041363
#
#         총자산대비잉여현금흐름
# 0         -0.221444
# 1          0.069046
# 2         -0.516536
# 3         -0.798633
# 4          0.418095
# ...             ...
# 137673     0.049512
# 137674     0.126453
# 137675     0.213073
# 137676     0.066068
# 137677     0.005828
#
# [137678 rows x 36 columns]

# %%
vif(mda_feature2)
# Out:
#     VIF Factor       features
# 0    12.714899           당좌비율
# 1    12.585796           유동비율
# 2     9.228735       순운전자본회전률
# 3     7.392161          자본분배율
# 4     7.003755        노동소득분배율
# 5     6.981452        유동자산회전률
# 6     6.659666         총자본회전률
# 7     5.239150        당좌자산회전률
# 8     5.009313       자기자본구성비율
# 9     3.222909         차입금의존도
# 10    2.768325      OCF이자보상배율
# 11    2.767090         이자보상배율
# 12    2.619128          이윤분배율
# 13    2.529854    총자산대비잉여현금흐름
# 14    2.209538        총자본순이익률
# 15    2.191502    총자산대비영업현금흐름
# 16    2.121277        총자본투자효율
# 17    2.088196        자기자본회전률
# 18    2.024375       매출액영업이익률
# 19    1.731938         총자본증가율
# 20    1.703824    매출액대비잉여현금흐름
# 21    1.691211          부가가치율
# 22    1.525409           부채비율
# 23    1.517726       자기자본순이익률
# 24    1.315893        유동자산증가율
# 25    1.254356      총자산대비현금흐름
# 26    1.222042        자기자본증가율
# 27    1.175898        운전자본회전률
# 28    1.150065         순이익증가율
# 29    1.141966        영업이익증가율
# 30    1.095297         매출액증가율
# 31    1.092210        재고자산증가율
# 32    1.060959        재고자산회전률
# 33    1.042630        유형자산증가율
# 34    1.031599  매출액대비금융비용상환능력
# 35    1.028126       장기부채상환능력

# %%
# 유동비율 삭제
fea = ['부채비율', '당좌비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
       '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률',
       '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율',
       '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율',
       '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'OCF이자보상배율',
       '장기부채상환능력', '매출액대비금융비용상환능력', '매출액대비잉여현금흐름', '총자산대비현금흐름',
       '총자산대비영업현금흐름', '총자산대비잉여현금흐름'
       ]
mda_feature3 = train[fea]
mda_feature3
# Out:
#            부채비율    당좌비율      이자보상배율  차입금의존도  자기자본구성비율  매출액영업이익률  자기자본순이익률  \
# 0       1251.02  347.96  -13.357516    6.09      7.40   -414.90   -826.27
# 1        107.19   68.72    8.709388   45.96     48.26     25.08     13.81
# 2        399.11  109.86 -198.699143    0.00     20.04    -17.15    -12.57
# 3        267.34   55.31   14.620331   70.59     27.22     60.12     66.76
# 4        390.03   30.73   13.221831    1.76     20.41     28.90    408.97
# ...         ...     ...         ...     ...       ...       ...       ...
# 137673   400.62   84.46   12.957288   19.60     19.98      6.17     67.90
# 137674   135.02  148.14    6.055733   25.22     42.55      4.29      9.33
# 137675    50.03  223.79   52.200088   18.78     66.65     20.22     58.72
# 137676    27.20  272.56  -21.661011    7.13     78.62      1.88      1.88
# 137677  3098.11    7.74    7.037306   32.75      3.13     24.77     68.38
#
#         총자본순이익률  총자본회전률  자기자본회전률  ...  노동소득분배율  자본분배율  이윤분배율   OCF이자보상배율  \
# 0        -82.59    0.17     2.28  ...     0.00   0.00   0.00   -9.332108
# 1          6.61    0.36     0.76  ...    20.76  79.24  42.80    9.548280
# 2         -1.80    0.10     0.68  ...    93.19   6.81 -30.69 -618.027372
# 3         18.17    0.40     1.48  ...    13.42  86.58  61.48    5.010647
# 4         27.88    1.17    17.19  ...     4.71  95.29  76.32   16.602420
# ...         ...     ...      ...  ...      ...    ...    ...         ...
# 137673    10.04    2.20    14.88  ...    44.31  55.69  32.77    4.818200
# 137674     3.32    3.04     8.55  ...    43.42  56.58  18.05    4.835895
# 137675    36.01    2.00     3.27  ...    22.43  77.57  59.76   40.753692
# 137676     1.43    0.88     1.15  ...    34.11  65.89  26.06   40.446933
# 137677     1.61    0.28    11.72  ...    37.74  62.26   9.48    4.299987
#
#         장기부채상환능력  매출액대비금융비용상환능력  매출액대비잉여현금흐름  총자산대비현금흐름  총자산대비영업현금흐름  \
# 0      -0.000000       4.174742    -2.629424   0.772454    -0.244115
# 1       2.352094      56.802819     0.189178   0.000884     0.100369
# 2      -0.000000     -23.752940    -3.552263  -0.373468    -0.518387
# 3       4.843848      26.994572    -3.969096  -0.149208     0.041456
# 4       0.000000      46.704264     0.362891  -0.001722     0.418095
# ...          ...            ...          ...        ...          ...
# 137673  0.000000     213.217431     0.022309  -0.003247     0.050929
# 137674  0.036460     195.625970     0.036524  -0.018967     0.118604
# 137675  0.163392     288.357414     0.128391   0.215584     0.262040
# 137676  0.295099    -288.743530     0.073553   0.063097     0.050614
# 137677  0.696463      32.488890     0.021335  -0.000420     0.041363
#
#         총자산대비잉여현금흐름
# 0         -0.221444
# 1          0.069046
# 2         -0.516536
# 3         -0.798633
# 4          0.418095
# ...             ...
# 137673     0.049512
# 137674     0.126453
# 137675     0.213073
# 137676     0.066068
# 137677     0.005828
#
# [137678 rows x 35 columns]

# %%
vif(mda_feature3)
# Out:
#     VIF Factor       features
# 0     9.228716       순운전자본회전률
# 1     7.392028          자본분배율
# 2     7.003737        노동소득분배율
# 3     6.906392        유동자산회전률
# 4     6.658317         총자본회전률
# 5     5.169877        당좌자산회전률
# 6     5.009258       자기자본구성비율
# 7     3.212213         차입금의존도
# 8     2.768261      OCF이자보상배율
# 9     2.767082         이자보상배율
# 10    2.618991          이윤분배율
# 11    2.529008    총자산대비잉여현금흐름
# 12    2.208223        총자본순이익률
# 13    2.177848    총자산대비영업현금흐름
# 14    2.121277        총자본투자효율
# 15    2.088179        자기자본회전률
# 16    2.024254       매출액영업이익률
# 17    1.731935         총자본증가율
# 18    1.702187    매출액대비잉여현금흐름
# 19    1.690999          부가가치율
# 20    1.525183           부채비율
# 21    1.517679       자기자본순이익률
# 22    1.315775        유동자산증가율
# 23    1.294925           당좌비율
# 24    1.254314      총자산대비현금흐름
# 25    1.222017        자기자본증가율
# 26    1.154401        운전자본회전률
# 27    1.150063         순이익증가율
# 28    1.141944        영업이익증가율
# 29    1.094816         매출액증가율
# 30    1.091483        재고자산증가율
# 31    1.060585        재고자산회전률
# 32    1.042288        유형자산증가율
# 33    1.031509  매출액대비금융비용상환능력
# 34    1.027825       장기부채상환능력

# %%
fea_hetero= ['부채비율', '당좌비율', '이자보상배율', '차입금의존도', '자기자본구성비율',
       '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률',
       '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율',
       '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율',
        '노동소득분배율', '자본분배율', '이윤분배율', 'OCF이자보상배율',
       '장기부채상환능력', '매출액대비금융비용상환능력', '매출액대비잉여현금흐름', '총자산대비영업현금흐름', '총자산대비잉여현금흐름']
fea_homo=['매출액영업이익률','총자본투자효율','부가가치율','총자산대비현금흐름']
# Welch's t-test 수행
t_stat, p_value = stats.ttest_ind(Bad[fea_hetero], Good[fea_hetero], equal_var=False)
result_df_hetero = pd.DataFrame({'t-statistic': t_stat, 'p-value': p_value}, index=fea_hetero)
# t-test 수행
t_stat, p_value = stats.ttest_ind(Bad[fea_homo], Good[fea_homo], equal_var=True)
result_df_homo = pd.DataFrame({'t-statistic': t_stat, 'p-value': p_value}, index=fea_homo)
result_df = pd.concat([result_df_hetero,result_df_homo],axis=0)
result_df = result_df.sort_values('p-value', ascending=True).reset_index()

# %%
result_df = result_df[['index', 'p-value']]
result_df.columns = ['Variable', 'p-value']

# %%
result_df
# Out:
#          Variable        p-value
# 0        자기자본구성비율   0.000000e+00
# 1     총자산대비잉여현금흐름   0.000000e+00
# 2         유동자산회전률   0.000000e+00
# 3          총자본회전률   0.000000e+00
# 4         당좌자산회전률   0.000000e+00
# 5        순운전자본회전률   0.000000e+00
# 6          차입금의존도  6.457497e-287
# 7         자기자본회전률  1.349787e-276
# 8          총자본증가율  4.577537e-271
# 9          순이익증가율  1.849513e-221
# 10        자기자본증가율  1.616300e-205
# 11        영업이익증가율  5.482185e-146
# 12        유동자산증가율  1.165196e-141
# 13        재고자산증가율   7.262461e-88
# 14         매출액증가율   1.272323e-61
# 15      OCF이자보상배율   7.471982e-49
# 16           당좌비율   6.581573e-40
# 17        유형자산증가율   8.487281e-38
# 18    총자산대비영업현금흐름   3.190395e-34
# 19         이자보상배율   4.012372e-30
# 20      총자산대비현금흐름   7.022219e-28
# 21        총자본순이익률   3.058969e-27
# 22           부채비율   1.939047e-25
# 23       장기부채상환능력   1.265657e-12
# 24          부가가치율   3.390951e-11
# 25          자본분배율   3.411584e-08
# 26  매출액대비금융비용상환능력   7.080683e-07
# 27        노동소득분배율   1.667814e-06
# 28    매출액대비잉여현금흐름   1.595170e-05
# 29       자기자본순이익률   1.035631e-04
# 30          이윤분배율   9.970591e-04
# 31        총자본투자효율   6.247574e-03
# 32        재고자산회전률   1.882372e-02
# 33        운전자본회전률   2.507721e-02
# 34       매출액영업이익률   3.430635e-02

# %% [markdown]
# ---

# %% [markdown]
# # Chi 2

# %% [markdown]
# * 카이제곱 검정 조건
#     * 종속변인은 범주형 자료여야 한다.
#     * 기대빈도가 5이하인 셀이 전체의 20%가 넘지 않아야 한다.
#     * 각 칸의 빈도는 다른 칸의 빈도와 독립적이어야 한다.

# %% [markdown]
# - 범주형 변수만 추출

# %%
train.columns
# Out:
# Index(['회사명', '거래소코드', 'Year', '부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도',
#        '자기자본구성비율', '매출액영업이익률', '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률',
#        '운전자본회전률', '순운전자본회전률', '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율',
#        '총자본증가율', '자기자본증가율', '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율',
#        '영업이익증가율', '총자본투자효율', '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'OCF이자보상배율',
#        '부채상환계수', '장기부채상환능력', '매출액대비금융비용상환능력', '연구개발비대비매출액', '매출액대비현금흐름',
#        '매출액대비잉여현금흐름', '총자산대비현금흐름', '총자산대비영업현금흐름', '총자산대비잉여현금흐름', '기업수명주기',
#        '이보배초과여부', '파부비초과여부', '파당비초과여부', '파차의초과여부', '파로이초과여부', 'log자산총계',
#        't-1감사의견코드'],
#       dtype='object')

# %%
train_cat = train[['기업수명주기', 't-1감사의견코드', '이보배초과여부', '파부비초과여부', '파당비초과여부', '파차의초과여부', '파로이초과여부']].astype('category')
test_cat = test[['기업수명주기', 't-1감사의견코드', '이보배초과여부', '파부비초과여부', '파당비초과여부', '파차의초과여부', '파로이초과여부']].astype('category')

# %%
X_train_cat = train_cat.drop('t-1감사의견코드', axis=1)
y_train_cat = train['t-1감사의견코드']
X_test_cat = test_cat.drop('t-1감사의견코드', axis=1)
y_test_cat = test['t-1감사의견코드']

# %%
# Chi-square 조건 확인
from scipy.stats import chi2_contingency

# 기대빈도가 5 이하인 항목의 비율을 저장할 딕셔너리
expected_freq_5_ratio = {}

# 각 독립 변수에 대해 기대빈도 계산 및 비율 확인
for column in train_cat.columns[:-1]:
    # 교차 테이블 생성
    contingency_table = pd.crosstab(train_cat[column], train_cat['t-1감사의견코드'])

    # 카이제곱 검정 수행
    chi2, p_value, dof, expected_freq = chi2_contingency(contingency_table)

    # 기대빈도가 5 이하인 항목의 비율 계산
    expected_freq_5 = (expected_freq <= 5).mean()

    # 결과 저장
    expected_freq_5_ratio[column] = expected_freq_5

# 결과 출력
for column, ratio in expected_freq_5_ratio.items():
    print(f"변수 '{column}'의 기대빈도가 5 이하인 항목 비율: {ratio}")
# Out:
# 변수 '기업수명주기'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 't-1감사의견코드'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 '이보배초과여부'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 '파부비초과여부'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 '파당비초과여부'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 '파차의초과여부'의 기대빈도가 5 이하인 항목 비율: 0.0

# %%
# 독립변수와 종속변수 간의 카이제곱 검정 수행
chi2_scores = []

for column in X_train_cat.columns:
    # 교차 테이블 생성
    contingency_table = pd.crosstab(X_train_cat[column], y_train_cat)
    chi2, p_value, dof, expected_freq = chi2_contingency(contingency_table)
    # 카이제곱 통계량(chi2), p-value(p_value), 자유도(dof), 예상빈도(expected_freq)
    print(p_value)
    chi2_scores.append((column, chi2))

# 카이제곱 검정 결과를 기준으로 변수 정렬
sorted_features = sorted(chi2_scores, key=lambda x : x[1], reverse=True)

# 선택된 변수 출력
sorted_features
# Out:
# 0.0
# 0.12908771021386392
# 0.0
# 0.00039229715645192347
# 0.0
# 1.9096172238484248e-59
# [('기업수명주기', 3089.2507048662806),
#  ('파차의초과여부', 1985.8292770838254),
#  ('파부비초과여부', 1906.060822214597),
#  ('파로이초과여부', 264.3747900999849),
#  ('파당비초과여부', 12.568529415290646),
#  ('이보배초과여부', 2.303441378969885)]

# %%
chi2_scores
# Out:
# [('기업수명주기', 3089.2507048662806),
#  ('이보배초과여부', 2.303441378969885),
#  ('파부비초과여부', 1906.060822214597),
#  ('파당비초과여부', 12.568529415290646),
#  ('파차의초과여부', 1985.8292770838254),
#  ('파로이초과여부', 264.3747900999849)]

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# 독립변수와 종속변수 간의 카이제곱 검정 수행
chi2_scores = []

p_values = []
for column in X_train_cat.columns:
    # 교차 테이블 생성
    contingency_table = pd.crosstab(X_train_cat[column], y_train_cat)
    chi2, p_value, dof, expected_freq = chi2_contingency(contingency_table)
    p_values.append(p_value)
    chi2_scores.append((column, chi2))

# p-value가 0.05보다 작은 값을 출력하는 데이터프레임 생성
result_df_1 = pd.DataFrame({'Variable': X_train_cat.columns, 'p-value': p_values})
filtered_df_chi = result_df_1[result_df_1['p-value'] < 0.05]

filtered_df_chi
# Out:
#   Variable       p-value
# 0   기업수명주기  0.000000e+00
# 2  파부비초과여부  0.000000e+00
# 3  파당비초과여부  3.922972e-04
# 4  파차의초과여부  0.000000e+00
# 5  파로이초과여부  1.909617e-59

# %%
result_df
# Out:
#          Variable        p-value
# 0        자기자본구성비율   0.000000e+00
# 1     총자산대비잉여현금흐름   0.000000e+00
# 2         유동자산회전률   0.000000e+00
# 3          총자본회전률   0.000000e+00
# 4         당좌자산회전률   0.000000e+00
# 5        순운전자본회전률   0.000000e+00
# 6          차입금의존도  6.457497e-287
# 7         자기자본회전률  1.349787e-276
# 8          총자본증가율  4.577537e-271
# 9          순이익증가율  1.849513e-221
# 10        자기자본증가율  1.616300e-205
# 11        영업이익증가율  5.482185e-146
# 12        유동자산증가율  1.165196e-141
# 13        재고자산증가율   7.262461e-88
# 14         매출액증가율   1.272323e-61
# 15      OCF이자보상배율   7.471982e-49
# 16           당좌비율   6.581573e-40
# 17        유형자산증가율   8.487281e-38
# 18    총자산대비영업현금흐름   3.190395e-34
# 19         이자보상배율   4.012372e-30
# 20      총자산대비현금흐름   7.022219e-28
# 21        총자본순이익률   3.058969e-27
# 22           부채비율   1.939047e-25
# 23       장기부채상환능력   1.265657e-12
# 24          부가가치율   3.390951e-11
# 25          자본분배율   3.411584e-08
# 26  매출액대비금융비용상환능력   7.080683e-07
# 27        노동소득분배율   1.667814e-06
# 28    매출액대비잉여현금흐름   1.595170e-05
# 29       자기자본순이익률   1.035631e-04
# 30          이윤분배율   9.970591e-04
# 31        총자본투자효율   6.247574e-03
# 32        재고자산회전률   1.882372e-02
# 33        운전자본회전률   2.507721e-02
# 34       매출액영업이익률   3.430635e-02

# %%
result = pd.concat([result_df, filtered_df_chi], axis=0)

# %%
result
# Out:
#          Variable        p-value
# 0        자기자본구성비율   0.000000e+00
# 1     총자산대비잉여현금흐름   0.000000e+00
# 2         유동자산회전률   0.000000e+00
# 3          총자본회전률   0.000000e+00
# 4         당좌자산회전률   0.000000e+00
# 5        순운전자본회전률   0.000000e+00
# 6          차입금의존도  6.457497e-287
# 7         자기자본회전률  1.349787e-276
# 8          총자본증가율  4.577537e-271
# 9          순이익증가율  1.849513e-221
# 10        자기자본증가율  1.616300e-205
# 11        영업이익증가율  5.482185e-146
# 12        유동자산증가율  1.165196e-141
# 13        재고자산증가율   7.262461e-88
# 14         매출액증가율   1.272323e-61
# 15      OCF이자보상배율   7.471982e-49
# 16           당좌비율   6.581573e-40
# 17        유형자산증가율   8.487281e-38
# 18    총자산대비영업현금흐름   3.190395e-34
# 19         이자보상배율   4.012372e-30
# 20      총자산대비현금흐름   7.022219e-28
# 21        총자본순이익률   3.058969e-27
# 22           부채비율   1.939047e-25
# 23       장기부채상환능력   1.265657e-12
# 24          부가가치율   3.390951e-11
# 25          자본분배율   3.411584e-08
# 26  매출액대비금융비용상환능력   7.080683e-07
# 27        노동소득분배율   1.667814e-06
# 28    매출액대비잉여현금흐름   1.595170e-05
# 29       자기자본순이익률   1.035631e-04
# 30          이윤분배율   9.970591e-04
# 31        총자본투자효율   6.247574e-03
# 32        재고자산회전률   1.882372e-02
# 33        운전자본회전률   2.507721e-02
# 34       매출액영업이익률   3.430635e-02
# 0          기업수명주기   0.000000e+00
# 2         파부비초과여부   0.000000e+00
# 3         파당비초과여부   3.922972e-04
# 4         파차의초과여부   0.000000e+00
# 5         파로이초과여부   1.909617e-59

# %%
result.sort_values('p-value', ascending=True).reset_index(drop=True)
# Out:
#          Variable        p-value
# 0        자기자본구성비율   0.000000e+00
# 1         파부비초과여부   0.000000e+00
# 2          기업수명주기   0.000000e+00
# 3        순운전자본회전률   0.000000e+00
# 4         파차의초과여부   0.000000e+00
# 5          총자본회전률   0.000000e+00
# 6         유동자산회전률   0.000000e+00
# 7     총자산대비잉여현금흐름   0.000000e+00
# 8         당좌자산회전률   0.000000e+00
# 9          차입금의존도  6.457497e-287
# 10        자기자본회전률  1.349787e-276
# 11         총자본증가율  4.577537e-271
# 12         순이익증가율  1.849513e-221
# 13        자기자본증가율  1.616300e-205
# 14        영업이익증가율  5.482185e-146
# 15        유동자산증가율  1.165196e-141
# 16        재고자산증가율   7.262461e-88
# 17         매출액증가율   1.272323e-61
# 18        파로이초과여부   1.909617e-59
# 19      OCF이자보상배율   7.471982e-49
# 20           당좌비율   6.581573e-40
# 21        유형자산증가율   8.487281e-38
# 22    총자산대비영업현금흐름   3.190395e-34
# 23         이자보상배율   4.012372e-30
# 24      총자산대비현금흐름   7.022219e-28
# 25        총자본순이익률   3.058969e-27
# 26           부채비율   1.939047e-25
# 27       장기부채상환능력   1.265657e-12
# 28          부가가치율   3.390951e-11
# 29          자본분배율   3.411584e-08
# 30  매출액대비금융비용상환능력   7.080683e-07
# 31        노동소득분배율   1.667814e-06
# 32    매출액대비잉여현금흐름   1.595170e-05
# 33       자기자본순이익률   1.035631e-04
# 34        파당비초과여부   3.922972e-04
# 35          이윤분배율   9.970591e-04
# 36        총자본투자효율   6.247574e-03
# 37        재고자산회전률   1.882372e-02
# 38        운전자본회전률   2.507721e-02
# 39       매출액영업이익률   3.430635e-02

# %% [markdown]
# ---

# %%
# 스케일링된 연속형 변수와 범주형 변수 합치기
logit_ = pd.concat([train_sc_total, X_train_cat], axis=1)
X_logit = logit_.drop('t-1감사의견코드', axis=1)
y_logit = logit_[['t-1감사의견코드']]

# %% [markdown]
# #### Feature 개수 정하기 위해 Logit

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import statsmodels.api as sm
import numpy as np
lr_clf = LogisticRegression()

feature = X_logit
target = y_logit

logit = SelectFromModel(LogisticRegression())
logit.fit(feature, target)
logit_support = logit.get_support()
lr_feature = feature.loc[:,logit_support].columns.tolist()

# %%
# 15개
lr_feature
# Out:
# ['자기자본구성비율',
#  '총자본순이익률',
#  '순운전자본회전률',
#  '당좌자산회전률',
#  '유동자산회전률',
#  '총자본증가율',
#  '자기자본증가율',
#  '순이익증가율',
#  '총자본투자효율',
#  'log자산총계',
#  '총자산대비현금흐름',
#  '총자산대비잉여현금흐름',
#  '파부비초과여부',
#  '파당비초과여부',
#  '파차의초과여부']

# %% [markdown]
# 자기자본구성비율	0.000000e+00
# 1	log자산총계	0.000000e+00
# 2	파부비초과여부	0.000000e+00
# 3	기업수명주기	0.000000e+00
# 4	파차의초과여부	0.000000e+00
# 5	총자본증가율	4.006026e-74
# 6	파로이초과여부	1.909617e-59
# 7	총자본회전률	8.385602e-36
# 8	총자산대비현금흐름	6.909689e-34
# 9	재고자산회전률	1.384389e-04
# 10	파당비초과여부	3.922972e-04
# 11	순이익증가율	6.370057e-04
# 12	총자본순이익률	8.639113e-04
# 13	순운전자본회전률	2.207923e-03
# 14	당좌비율	8.492177e-03
# 15	OCF이자보상배율	1.071066e-02
# 16	매출액대비금융비용상환능력	1.237392e-02
# 17	영업이익증가율	1.350113e-02
# 18	자기자본회전률	2.742223e-02
# 19	차입금의존도	2.846012e-02
# 20	장기부채상환능력	3.315100e-02

# %% [markdown]
# ---

# %% [markdown]
# ### Embedded Method

# %% [markdown]
# > Randomforeset

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
selector = SelectFromModel(estimator=RandomForestClassifier(), threshold=0.02398).fit(X_logit, y_logit)
rf = selector.get_support()
count = np.count_nonzero(rf)
count
# Out:
# 15

# %%
rf_features = X_logit.loc[:, rf].columns.tolist()
rf_features
# Out:
# ['자기자본순이익률',
#  '총자본회전률',
#  '자기자본회전률',
#  '순운전자본회전률',
#  '재고자산회전률',
#  '당좌자산회전률',
#  '매출액증가율',
#  '총자본증가율',
#  '자기자본증가율',
#  '유형자산증가율',
#  '유동자산증가율',
#  '부가가치율',
#  'log자산총계',
#  '매출액대비금융비용상환능력',
#  '총자산대비잉여현금흐름']

# %% [markdown]
# > LASSO

# %%
lasso = SelectFromModel(estimator=LogisticRegression(penalty='l1', solver='liblinear', C=0.0015)).fit(X_logit, y_logit)
lasso_support = lasso.get_support()
lasso_feature = X_logit.loc[:,lasso_support].columns.tolist()

# %%
len(lasso_feature)
# Out:
# 15

# %%
lasso_feature
# Out:
# ['자기자본구성비율',
#  '총자본순이익률',
#  '자기자본회전률',
#  '순운전자본회전률',
#  '당좌자산회전률',
#  '유동자산회전률',
#  '총자본증가율',
#  '자기자본증가율',
#  '영업이익증가율',
#  '총자본투자효율',
#  'log자산총계',
#  '매출액대비잉여현금흐름',
#  '총자산대비현금흐름',
#  '총자산대비잉여현금흐름',
#  '기업수명주기']

# %% [markdown]
# # Wrapper Method

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector

# %%
selector = SequentialFeatureSelector(estimator=LogisticRegression(), n_features_to_select=15, direction='backward', scoring='f1', cv=5, n_jobs=-1)

# 변수 선택 수행
selector.fit(X_logit, y_logit)

# 선택된 변수의 인덱스
selected_features = selector.get_support(indices=True)

# 선택된 변수 출력
for i in selected_features:
    print(X_logit.columns[i])
# Out:
# 부채비율
# 총자본순이익률
# 순운전자본회전률
# 당좌자산회전률
# 유동자산회전률
# 총자본증가율
# 총자본투자효율
# log자산총계
# 매출액대비잉여현금흐름
# 총자산대비현금흐름
# 총자산대비영업현금흐름
# 총자산대비잉여현금흐름
# 기업수명주기
# 파부비초과여부
# 파차의초과여부

# %%
selected_columns = X_logit.columns[selected_features]
wrapper_features = list(selected_columns)

# %% [markdown]
# # 종합

# %%
result = result.sort_values('p-value', ascending=True).reset_index(drop=True)
result = result.head(15)
filter = result[['Variable']]

# %%
rf_features = pd.DataFrame(rf_features)
lasso_features = pd.DataFrame(lasso_feature)
wrapper_features = pd.DataFrame(wrapper_features)

# %%
total = pd.concat([filter, rf_features, lasso_features, wrapper_features], axis=1)

# %%
total.columns = ['t&chi', 'rf', 'lasso', 'wrapper']
total
# Out:
#           t&chi             rf        lasso      wrapper
# 0      자기자본구성비율       자기자본순이익률     자기자본구성비율         부채비율
# 1       파부비초과여부         총자본회전률      총자본순이익률      총자본순이익률
# 2        기업수명주기        자기자본회전률      자기자본회전률     순운전자본회전률
# 3      순운전자본회전률       순운전자본회전률     순운전자본회전률      당좌자산회전률
# 4       파차의초과여부        재고자산회전률      당좌자산회전률      유동자산회전률
# 5        총자본회전률        당좌자산회전률      유동자산회전률       총자본증가율
# 6       유동자산회전률         매출액증가율       총자본증가율      총자본투자효율
# 7   총자산대비잉여현금흐름         총자본증가율      자기자본증가율      log자산총계
# 8       당좌자산회전률        자기자본증가율      영업이익증가율  매출액대비잉여현금흐름
# 9        차입금의존도        유형자산증가율      총자본투자효율    총자산대비현금흐름
# 10      자기자본회전률        유동자산증가율      log자산총계  총자산대비영업현금흐름
# 11       총자본증가율          부가가치율  매출액대비잉여현금흐름  총자산대비잉여현금흐름
# 12       순이익증가율        log자산총계    총자산대비현금흐름       기업수명주기
# 13      자기자본증가율  매출액대비금융비용상환능력  총자산대비잉여현금흐름      파부비초과여부
# 14      영업이익증가율    총자산대비잉여현금흐름       기업수명주기      파차의초과여부

# %%
filter = total['t&chi'].tolist()
rf = total['rf'].tolist()
lasso = total['lasso'].tolist()
wrapper = total['wrapper'].tolist()

# %%
X_logit.columns
# Out:
# Index(['부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
#        '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률',
#        '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율',
#        '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율',
#        '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'log자산총계', 'OCF이자보상배율', '부채상환계수',
#        '장기부채상환능력', '매출액대비금융비용상환능력', '연구개발비대비매출액', '매출액대비현금흐름', '매출액대비잉여현금흐름',
#        '총자산대비현금흐름', '총자산대비영업현금흐름', '총자산대비잉여현금흐름', '기업수명주기', '이보배초과여부',
#        '파부비초과여부', '파당비초과여부', '파차의초과여부', '파로이초과여부'],
#       dtype='object')

# %%
total_result = pd.DataFrame(index=X_logit.columns)

# 각 컬럼의 값에 인덱스 포함 여부에 따라 True 또는 False 입력
total_result['t&chi'] = total_result.index.isin(filter)
total_result['wrapper'] = total_result.index.isin(wrapper)
total_result['rf'] = total_result.index.isin(rf)
total_result['lasso'] = total_result.index.isin(lasso)
total_result["true_sum"] = total_result.sum(axis=1)

total_result.sort_values('true_sum', ascending=False, inplace=True)
total_result
# Out:
#                t&chi  wrapper     rf  lasso  true_sum
# 총자본증가율          True     True   True   True         4
# 총자산대비잉여현금흐름     True     True   True   True         4
# 당좌자산회전률         True     True   True   True         4
# 순운전자본회전률        True     True   True   True         4
# 자기자본회전률         True    False   True   True         3
# log자산총계        False     True   True   True         3
# 자기자본증가율         True    False   True   True         3
# 기업수명주기          True     True  False   True         3
# 유동자산회전률         True     True  False   True         3
# 총자산대비현금흐름      False     True  False   True         2
# 매출액대비잉여현금흐름    False     True  False   True         2
# 영업이익증가율         True    False  False   True         2
# 총자본투자효율        False     True  False   True         2
# 총자본회전률          True    False   True  False         2
# 총자본순이익률        False     True  False   True         2
# 자기자본구성비율        True    False  False   True         2
# 파부비초과여부         True     True  False  False         2
# 파차의초과여부         True     True  False  False         2
# 총자산대비영업현금흐름    False     True  False  False         1
# 매출액대비금융비용상환능력  False    False   True  False         1
# 부가가치율          False    False   True  False         1
# 부채비율           False     True  False  False         1
# 재고자산회전률        False    False   True  False         1
# 유동자산증가율        False    False   True  False         1
# 유형자산증가율        False    False   True  False         1
# 순이익증가율          True    False  False  False         1
# 차입금의존도          True    False  False  False         1
# 매출액증가율         False    False   True  False         1
# 자기자본순이익률       False    False   True  False         1
# 재고자산증가율        False    False  False  False         0
# 유동비율           False    False  False  False         0
# 파당비초과여부        False    False  False  False         0
# 이자보상배율         False    False  False  False         0
# 이보배초과여부        False    False  False  False         0
# 매출액영업이익률       False    False  False  False         0
# 운전자본회전률        False    False  False  False         0
# 연구개발비대비매출액     False    False  False  False         0
# 매출액대비현금흐름      False    False  False  False         0
# 당좌비율           False    False  False  False         0
# 장기부채상환능력       False    False  False  False         0
# 부채상환계수         False    False  False  False         0
# OCF이자보상배율      False    False  False  False         0
# 이윤분배율          False    False  False  False         0
# 자본분배율          False    False  False  False         0
# 노동소득분배율        False    False  False  False         0
# 파로이초과여부        False    False  False  False         0

# %%
total_result_2 = total_result[total_result['true_sum']>=2]
total_result_2.reset_index()
# Out:
#           index  t&chi  wrapper     rf  lasso  true_sum
# 0        총자본증가율   True     True   True   True         4
# 1   총자산대비잉여현금흐름   True     True   True   True         4
# 2       당좌자산회전률   True     True   True   True         4
# 3      순운전자본회전률   True     True   True   True         4
# 4       자기자본회전률   True    False   True   True         3
# 5       log자산총계  False     True   True   True         3
# 6       자기자본증가율   True    False   True   True         3
# 7        기업수명주기   True     True  False   True         3
# 8       유동자산회전률   True     True  False   True         3
# 9     총자산대비현금흐름  False     True  False   True         2
# 10  매출액대비잉여현금흐름  False     True  False   True         2
# 11      영업이익증가율   True    False  False   True         2
# 12      총자본투자효율  False     True  False   True         2
# 13       총자본회전률   True    False   True  False         2
# 14      총자본순이익률  False     True  False   True         2
# 15     자기자본구성비율   True    False  False   True         2
# 16      파부비초과여부   True     True  False  False         2
# 17      파차의초과여부   True     True  False  False         2

# %%
total_result_2.index
# Out:
# Index(['총자본증가율', '총자산대비잉여현금흐름', '당좌자산회전률', '순운전자본회전률', '자기자본회전률', 'log자산총계',
#        '자기자본증가율', '기업수명주기', '유동자산회전률', '총자산대비현금흐름', '매출액대비잉여현금흐름', '영업이익증가율',
#        '총자본투자효율', '총자본회전률', '총자본순이익률', '자기자본구성비율', '파부비초과여부', '파차의초과여부'],
#       dtype='object')
