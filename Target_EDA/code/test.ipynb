# %%
import pandas as pd

# %%
df5 = pd.read_csv('../data/중소기업_5.csv', encoding='cp949')
df5
# Out:
#                        회사명   거래소코드     회계년도    산업코드  \
# 0      (유)에스케이씨에보닉페록사이드코리아   93338  2019/12   32001
# 1      (유)에스케이씨에보닉페록사이드코리아   93338  2020/12   32001
# 2      (유)에스케이씨에보닉페록사이드코리아   93338  2021/12   32001
# 3      (유)에스케이씨에보닉페록사이드코리아   93338  2022/12   32001
# 4                    (유)연세   93779  2019/12  126801
# ...                    ...     ...      ...     ...
# 22320       위례의료복합피에프브이(주)  104256  2021/12  126801
# 22321       위례의료복합피에프브이(주)  104256  2022/12  126801
# 22322             위로지스주식회사   98894  2020/12  126802
# 22323             위로지스주식회사   98894  2021/12  126802
# 22324             위로지스주식회사   98894  2022/12  126802
#
#                              산업명         설립일 상장일  기업규모코드 감사의견코드
# 0        화학물질 및 화학제품 제조업; 의약품 제외  2006/08/01   0    20.0    NaN
# 1        화학물질 및 화학제품 제조업; 의약품 제외  2006/08/01   0    30.0     UQ
# 2        화학물질 및 화학제품 제조업; 의약품 제외  2006/08/01   0    20.0     UQ
# 3        화학물질 및 화학제품 제조업; 의약품 제외  2006/08/01   0    20.0     UQ
# ...

# %%
df6 = pd.read_csv('../data/중소기업_6.csv', encoding='cp949')
df6
# Out:
#              회사명   거래소코드     회계년도    산업코드               산업명         설립일  \
# 0      (유)유맥에프앤알   14534  2012/12  126801              부동산업  1997/04/14
# 1      (유)유맥에프앤알   14534  2013/12  126801              부동산업  1997/04/14
# 2      (유)유맥에프앤알   14534  2014/12  126801              부동산업  1997/04/14
# 3      (유)유맥에프앤알   14534  2015/12  126801              부동산업  1997/04/14
# 4      (유)유맥에프앤알   14534  2016/12  126801              부동산업  1997/04/14
# ...          ...     ...      ...     ...               ...         ...
# 22199   주식회사기남금속   89593  2019/12   32403         1차 금속 제조업  2008/01/01
# 22200   주식회사기남금속   89593  2021/12   32403         1차 금속 제조업  2008/01/01
# 22201   주식회사기남금속   89593  2022/12   32403         1차 금속 제조업  2008/01/01
# 22202   주식회사기남테크  106187  2021/12   32902    기타 기계 및 장비 제조업  2005/03/02
# 22203   주식회사기남테크  106187  2022/12   32902    기타 기계 및 장비 제조업  2005/03/02
#
#               상장일  기업규모코드 감사의견코드
# 0      0000/00/00    20.0     UQ
# 1      0000/00/00    30.0     UQ
# ...

# %%
df7 = pd.read_csv('../data/중소기업_7.csv', encoding='cp949')
df7
# Out:
#              회사명   거래소코드     회계년도    산업코드                산업명         설립일 상장일  \
# 0         주식회사기량  104623  2021/12  126801               부동산업  2020/06/24   0
# 1         주식회사기량  104623  2022/12  126801               부동산업  2020/06/24   0
# 2         주식회사기로   93269  2019/12  137105            전문 서비스업  2019/04/16   0
# 3         주식회사기로   93269  2020/12  137105            전문 서비스업  2019/04/16   0
# 4         주식회사기로   93269  2021/12  137105            전문 서비스업  2019/04/16   0
# ...          ...     ...      ...     ...                ...         ...  ..
# 20454  주식회사성우플라텍   66193  2020/12   32202    고무 및 플라스틱제품 제조업  2006/06/14   0
# 20455  주식회사성우플라텍   66193  2021/12   32202    고무 및 플라스틱제품 제조업  2006/06/14   0
# 20456  주식회사성우플라텍   66193  2022/12   32202    고무 및 플라스틱제품 제조업  2006/06/14   0
# 20457     주식회사성운  103217  2021/12   64204           전문직별 공사업  1999/01/01   0
# 20458     주식회사성운  103217  2022/12   64204           전문직별 공사업  1999/01/01   0
#
#        기업규모코드 감사의견코드
# 0        20.0    NaN
# ...

# %%
df8 = pd.read_csv('../data/중소기업_8.csv', encoding='cp949')
df8
# Out:
#              회사명   거래소코드     회계년도    산업코드       산업명         설립일         상장일  \
# 0         주식회사성운   29283  2012/12  126801      부동산업  1999/02/11  0000/00/00
# 1         주식회사성운   29283  2013/12  126801      부동산업  1999/02/11  0000/00/00
# 2         주식회사성운   29283  2014/12  126801      부동산업  1999/02/11  0000/00/00
# 3         주식회사성운   29283  2015/12  126801      부동산업  1999/02/11  0000/00/00
# 4         주식회사성운   29283  2016/12  126801      부동산업  1999/02/11  0000/00/00
# ...          ...     ...      ...     ...       ...         ...         ...
# 20546   주식회사이든건설   97621  2021/12  126800      부동산업  2019/02/18           0
# 20547   주식회사이든건설  103178  2021/12   64101    종합 건설업  2020/03/23           0
# 20548   주식회사이든건설  103178  2022/12   64101    종합 건설업  2020/03/23           0
# 20549  주식회사이든디엔씨  103209  2021/12  126802      부동산업  2013/12/19           0
# 20550  주식회사이든디엔씨  103209  2022/12  126802      부동산업  2013/12/19           0
#
#        기업규모코드 감사의견코드
# 0        20.0     UQ
# ...

# %%
len(df5['회사명'].unique())
# Out:
# 4059

# %%
len(df6['회사명'].unique())
# Out:
# 4034

# %%
len(df7['회사명'].unique())
# Out:
# 4148

# %%
len(df8['회사명'].unique())
# Out:
# 4233

# %%
len(df6['회사명'].unique())+len(df7['회사명'].unique())+len(df8['회사명'].unique())
# Out:
# 12415
