# %%
import pandas as pd

# %%
df2019 = pd.read_csv('../data/상장회사_감사의견2019-2022/상장회사_감사의견2019.csv')

# %%
df2019 = df2019.set_axis(df2019.iloc[1], axis=1)

# %%
df2019 = df2019.drop([0, 1])

# %%
# df2019.to_csv('상장회사_감사의견2019.csv', index=False)

# %%
df2020 = pd.read_excel('../data/회계감사의견2020.xls')

# %%
df2020 = df2020.set_axis(df2020.iloc[1], axis=1)
df2020 = df2020.drop([0, 1])
df2020
# Out:
# 1        회사명       사업연도     감사인  감사의견 감사보고서 특기사항  \
# 2         3S   제30기(당기)  신한회계법인    적정          -
# 3         3S   제29기(전기)  신한회계법인    적정          -
# 4         3S  제28기(전전기)  신한회계법인    적정          -
# 5     AJ네트웍스   제21기(당기)  삼일회계법인    적정          -
# 6     AJ네트웍스   제20기(전기)  삼정회계법인    적정          -
# ...      ...        ...     ...   ...        ...
# 8791    힐세리온    제8기(전기)  선진회계법인    적정          -
# 8792    힐세리온   제7기(전전기)  한울회계법인    적정          -
# 8793      힘스   제22기(당기)  인덕회계법인  적정의견          -
# 8794      힘스   제21기(전기)  인덕회계법인  적정의견          -
# 8795      힘스  제20기(전전기)  인덕회계법인  적정의견          -
#
# 1                                                강조사항 등  \
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                  (*1)
# 6                                                   NaN
# ...

# %%
# df2020.to_csv('상장회사_감사의견2020.csv', index=False)

# %%
df2021 = pd.read_excel('../data/회계감사의견2021.xls')
df2021
# Out:
#      「공시정보 활용마당」에서 제공하는 모든 정보는 공시의무자(제출인) 책임하에 작성된 공시자료 일부를 제공하는 것으로 금융감독원은 정보의 정확성 및 완전성을 보장하지 않습니다. 자세한 사항은 해당 보고서를 참조하시기 바랍니다.  \
# 0                                                   NaN
# 1                                                   회사명
# 2                                                    3S
# 3                                                    3S
# 4                                                    3S
# ...                                                 ...
# 9195                                                 희림
# 9196                                                 희림
# 9197                                                 힘스
# 9198                                                 힘스
# 9199                                                 힘스
#
#      Unnamed: 1            Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0           NaN                   NaN        NaN         NaN        NaN
# 1          사업연도                   감사인       감사의견  감사보고서 특기사항     강조사항 등
# ...

# %%
df2021 = df2021.set_axis(df2021.iloc[1], axis=1)
df2021 = df2021.drop([0, 1])
df2021
# Out:
# 1        회사명       사업연도                   감사인  감사의견 감사보고서 특기사항         강조사항 등  \
# 2         3S   제31기(당기)                신한회계법인    적정          -            NaN
# 3         3S   제30기(전기)                신한회계법인    적정          -            NaN
# 4         3S  제29기(전전기)                신한회계법인    적정          -            NaN
# 5     AJ네트웍스   제22기(당기)                삼일회계법인    적정          -  Covid-19 강조사항
# 6     AJ네트웍스   제21기(전기)                삼일회계법인    적정          -            NaN
# ...      ...        ...                   ...   ...        ...            ...
# 9195      희림   제31기(전기)  동현회계법인\n((구)영앤진회계법인)    적정          -            NaN
# 9196      희림  제30기(전전기)               영앤진회계법인    적정          -            NaN
# 9197      힘스    23기(당기)                다산회계법인  적정의견          -            NaN
# 9198      힘스   제22기(전기)                인덕회계법인  적정의견          -            NaN
# 9199      힘스  제21기(전전기)                인덕회계법인  적정의견          -            NaN
#
# ...

# %%
# df2021.to_csv('상장회사_감사의견2021.csv', index=False)

# %%
df2022 = pd.read_excel('../data/회계감사의견2022.xls')
df2022
# Out:
#      「공시정보 활용마당」에서 제공하는 모든 정보는 공시의무자(제출인) 책임하에 작성된 공시자료 일부를 제공하는 것으로 금융감독원은 정보의 정확성 및 완전성을 보장하지 않습니다. 자세한 사항은 해당 보고서를 참조하시기 바랍니다.  \
# 0                                                   NaN
# 1                                                   회사명
# 2                                                    3S
# 3                                                    3S
# 4                                                    3S
# ...                                                 ...
# 9507                                                 희림
# 9508                                                 희림
# 9509                                                 힘스
# 9510                                                 힘스
# 9511                                                 힘스
#
#      Unnamed: 1            Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0           NaN                   NaN        NaN         NaN        NaN
# 1          사업연도                   감사인       감사의견  감사보고서 특기사항     강조사항 등
# ...

# %%
df2022 = df2022.set_axis(df2022.iloc[1], axis=1)
df2022 = df2022.drop([0, 1])
df2022
# Out:
# 1        회사명       사업연도                   감사인  감사의견 감사보고서 특기사항         강조사항 등  \
# 2         3S   제32기(당기)                신한회계법인    적정          -            NaN
# 3         3S   제31기(전기)                신한회계법인    적정          -            NaN
# 4         3S  제30기(전전기)                신한회계법인    적정          -            NaN
# 5     AJ네트웍스   제23기(당기)                삼일회계법인   NaN          -            NaN
# 6     AJ네트웍스   제22기(전기)                삼일회계법인    적정          -  Covid-19 강조사항
# ...      ...        ...                   ...   ...        ...            ...
# 9507      희림   제32기(전기)                동현회계법인    적정          -            NaN
# 9508      희림  제31기(전전기)  동현회계법인\n((구)영앤진회계법인)    적정          -            NaN
# 9509      힘스   제24기(당기)                다산회계법인  적정의견          -            NaN
# 9510      힘스   제23기(전기)                다산회계법인  적정의견          -            NaN
# 9511      힘스   제22기(전기)                인덕회계법인  적정의견          -            NaN
#
# ...

# %%
# df2022.to_csv('상장회사_감사의견2022.csv', index=False)

# %%
df2019['강조사항 등'].str.contains('불확실성')
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 8563    NaN
# 8564    NaN
# 8565    NaN
# 8566    NaN
# 8567    NaN
# Name: 강조사항 등, Length: 8568, dtype: object
