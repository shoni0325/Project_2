# %%
import pandas as pd

#워닝 메시지
import warnings
warnings.filterwarnings('ignore')

import numpy as np

# %%
df = pd.read_csv('../data/t-1_raw_외감_1.csv', encoding='euc-kr')

# %%
df
# Out:
#                 회사명   거래소코드     회계년도  산업분류코드       부채비율     당좌비율     유동비율  \
# 0          (주)포스코건설   10000  2012/12      41     173.49   124.35   149.99
# 1          (주)포스코건설   10000  2013/12      41     130.89   120.59   146.23
# 2          (주)포스코건설   10000  2014/12      41     120.92   125.34   153.62
# 3          (주)포스코건설   10000  2015/12      41     100.59   145.66   164.20
# 4          (주)포스코건설   10000  2016/12      41     145.02   109.23   133.86
# ...             ...     ...      ...     ...        ...      ...      ...
# 188702  주식회사디벨롭파트너스  107270  2021/12      68  207716.86   159.52   159.90
# 188703    주식회사비바웨이브  107272  2021/12      47      12.22   772.88   933.46
# 188704    (주)경기화학물류  107273  2021/12      49     192.42   259.26   336.89
# 188705      주식회사일그램  107276  2021/12      71      99.28  1838.90  1838.90
# 188706    (주)두산종합건재  107278  2021/12      46     273.78   376.36   394.26
#
#               이자보상배율      OCF(천원)    이자비용(천원)  ...      자산총계(천원)  \
# ...

# %% [markdown]
# # 변수 뜯어보기

# %%
df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '산업분류코드', '부채비율', '당좌비율', '유동비율', '이자보상배율',
#        'OCF(천원)', '이자비용(천원)', '차입금의존도', '자기자본구성비율', '당기순이익(천원)', '감가상각비(백만원)',
#        '금융비용(백만원)', '단기차입금(천원)', '유동성장기부채(천원)', '장기차입금(천원)', '법인세비용차감전손익(백만원)',
#        '매출액영업이익률', '자기자본순이익률', '총자본순이익률', '매출액(천원)', '총자본회전률', '자기자본회전률',
#        '운전자본회전률', '순운전자본회전률', '재고자산회전률', '당좌자산회전률', '유동자산회전률', '매출액증가율',
#        '총자본증가율', '자기자본증가율', '순이익증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율',
#        '영업이익증가율', '총자본투자효율', '부가가치율', '노동소득분배율', '자본분배율', '이윤분배율', 'ICF(천원)',
#        'FCF(천원)', '자산총계(천원)', '부채총계(천원)', '자본총계(천원)', '산업분류', '자본금(천원)',
#        '영업손익(천원)', '연구개발비(천원)', '자본잠식률', 'Year', 't-1감사의견코드'],
#       dtype='object')

# %% [markdown]
# 금융비용(백만원)', '단기차입금(천원)', '유동성장기부채(천원)', '장기차입금(천원)', '법인세비용차감전손익(백만원)',
#        '매출액영업이익률', '자기자본순이익률', '총자본순이익률', '매출액(천원)', '총자본회전률', '자기자본회전률',

# %%
df.describe()
# Out:
#                거래소코드         산업분류코드          부채비율          당좌비율          유동비율  \
# count  188707.000000  188707.000000  1.886500e+05  1.886500e+05  1.886500e+05
# mean    57672.474339      44.055255  1.797187e+04  4.346751e+03  5.463465e+03
# std     25367.516420      20.438501  5.507996e+06  6.081015e+05  6.800613e+05
# min     10000.000000       1.000000 -6.280000e+00 -5.400000e-01 -5.400000e-01
# 25%     41840.000000      26.000000  4.163250e+01  3.659000e+01  6.522000e+01
# 50%     59716.000000      42.000000  1.363750e+02  8.642500e+01  1.195600e+02
# 75%     76684.000000      68.000000  3.461875e+02  1.721500e+02  2.212975e+02
# max    107278.000000      98.000000  2.373601e+09  1.715128e+08  1.715128e+08
#
#              이자보상배율       OCF(천원)      이자비용(천원)         차입금의존도       자기자본구성비율  \
# count  1.886500e+05  1.886520e+05  1.886520e+05  188650.000000  188650.000000
# mean   1.264920e+08  3.878672e+06  1.009580e+06      40.997030      38.188565
# ...

# %%
df[df['이자비용(천원)']==0]['이자보상배율']=
# Out:
# 39        999999999.0
# 40        999999999.0
# 41        999999999.0
# 83        999999999.0
# 84        999999999.0
#              ...
# 188681    999999999.0
# 188694    999999999.0
# 188695    999999999.0
# 188696    999999999.0
# 188703    999999999.0
# Name: 이자보상배율, Length: 23952, dtype: float64

# %%
df['부채비율'].value_counts()
# Out:
# 0.00         16690
# 0.01            56
# 0.02            28
# 0.04            23
# 18.53           21
#              ...
# 1615.30          1
# 1438.74          1
# 1126.70          1
# 1412.83          1
# 207716.86        1
# Name: 부채비율, Length: 72194, dtype: int64

# %%
df[(df['이자비용(천원)']==0)&(df['t-1감사의견코드']==1)]
# Out:
#                 회사명   거래소코드     회계년도  산업분류코드       부채비율    당좌비율    유동비율  \
# 1617       (주)호텔캐피탈   10529  2014/09      55      41.43  223.77  225.58
# 2751       (주)유정메디칼   11318  2013/12      63       0.00    0.00    0.00
# 3284         (주)팍스넷   12442  2015/12      63      23.30  459.07  459.07
# 5507    노보자임스코리아(주)   13438  2020/12      46      28.44  230.26  448.55
# 6240        대양건설(주)   13689  2012/12      41       0.00  181.98  198.80
# ...             ...     ...      ...     ...        ...     ...     ...
# 188661      (주)아르띠앙  107135  2021/12      68       0.00   25.38  313.33
# 188672   주식회사케이피홀딩스  107154  2021/12      68   27169.77   51.45  143.15
# 188677     주식회사창하산업  107166  2021/12      68  123634.75    3.27   99.62
# 188681  태안도시에너지주식회사  107181  2021/12      41     574.77    1.35    1.35
# 188694       (주)꼬르망  107239  2021/12      14      51.12  187.93  187.93
#
#              이자보상배율     OCF(천원)  이자비용(천원)  ...    자산총계(천원)    부채총계(천원)  \
# ...

# %%
# '이자보상배율' 열의 데이터 타입을 숫자로 변환
df['이자보상배율'] = pd.to_numeric(df['이자보상배율'], errors='coerce')

# %%
trim_pct = 0.005
lower_bound = np.percentile(df, trim_pct * 100)
upper_bound = np.percentile(df, (1 - trim_pct) * 100)
df = df[(df >= lower_bound) & (df <= upper_bound)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 trim_pct = 0.005
# ----> 2 lower_bound = np.percentile(df, trim_pct * 100)
#       3 upper_bound = np.percentile(df, (1 - trim_pct) * 100)
#       4 df = df[(df >= lower_bound) & (df <= upper_bound)]
#
# File <__array_function__ internals>:180, in percentile(*args, **kwargs)
#
# File c:\Users\shoni\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:4166, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4164 if not _quantile_is_valid(q):
#    4165     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4166 return _quantile_unchecked(
#    4167     a, q, axis, out, overwrite_input, method, keepdims)
#
# ...
